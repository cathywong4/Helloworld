# %% [markdown]
# # Time series forecast by ARIMA, Prophet, Holt-Winters
#
# Data source: https://www.kaggle.com/arashnic/learn-time-series-forecasting-from-gold-price
#
# Description: gold price from 1970-01-01 to 2020-03-13

# %%
import pandas as pd
import numpy as np

# %%
#set date as index
df = pd.read_csv('gold_price_data.csv',index_col='Date', parse_dates=['Date'], dayfirst=False)

# %%
#gold price is not collected in daily basis at the beginning
df.head(10)
# Out:
#             Value
# Date
# 1970-01-01   35.2
# 1970-04-01   35.1
# 1970-07-01   35.4
# 1970-10-01   36.2
# 1971-01-01   37.4
# 1971-04-01   38.9
# 1971-07-01   40.1
# 1971-10-01   42.0
# 1972-01-03   43.5
# 1972-04-03   48.3

# %%
#gold price almost collected in daily basis later
df.tail(10)
# Out:
#               Value
# Date
# 2020-03-02  1599.65
# 2020-03-03  1615.50
# 2020-03-04  1641.85
# 2020-03-05  1659.60
# 2020-03-06  1683.65
# 2020-03-09  1672.50
# 2020-03-10  1655.70
# 2020-03-11  1653.75
# 2020-03-12  1570.70
# 2020-03-13  1562.80

# %%
df.shape
# Out:
# (10787, 1)

# %%
df.isnull().sum()
# Out:
# Value    0
# dtype: int64

# %%
df.describe()
# Out:
#               Value
# count  10787.000000
# mean     653.596634
# std      434.030848
# min       35.100000
# 25%      349.200000
# 50%      409.350000
# 75%     1061.625000
# max     1895.000000

# %%
df.plot()

# %% [markdown]
# #

# %%
import matplotlib.pyplot as plt
from pylab import rcParams

# %%
#convert time series to a frequency of year. Original frequency is quarterly
df.asfreq('Y').plot()

# %%
df.asfreq('M').plot()

# %% [markdown]
# # Shifting and lags

# %%
#compare time series with a past of itself
plt.plot(df, label='Original')
plt.plot(df.shift(300), label='Lagged')
plt.legend()
plt.show()

# %%
#change in absolute no
df.diff().plot()

# %%
#% change
df.pct_change().plot()

# %%
#approx. interval of first 50 rows is ranged from month to quartar
df[:50].pct_change().plot()

# %%
#data from around 1979 is more completed (daily)
#periods: shift for forming percent change to have briefly monthly %change
df[51:].pct_change(periods=30).plot()

# %%
df[60:]
# Out:
#               Value
# Date
# 1979-02-01   229.35
# 1979-02-02   230.30
# 1979-02-05   243.10
# 1979-02-06   244.50
# 1979-02-07   251.60
# ...             ...
# 2020-03-09  1672.50
# 2020-03-10  1655.70
# 2020-03-11  1653.75
# 2020-03-12  1570.70
# 2020-03-13  1562.80
#
# [10727 rows x 1 columns]

# %% [markdown]
# # Time Series Components

# %% [markdown]
# - 3 systematic components: level, trend, seasonality
# - 1 non-systematic component: noise
#
#     - Level: average value
#     - Trend: increasing/ decreasing value
#     - Seasonality: repeating short-term cycle
#     - Noise: random variation

# %%
from statsmodels.tsa.seasonal import seasonal_decompose

# %%
rcParams['figure.figsize'] = 5,5

result = seasonal_decompose(df, model='multiplicative', period=120)
result.plot()
plt.show()

# %% [markdown]
# # Stationarity
# - constant mean
# - constant variance
# - autocovariance thta does not depend on time
#
# i.e. mean, variance, and autocorrelation do not change with time
#
# 2 popular test:
# 1. Rolling statistics
# 2. ADCF test

# %%
#original df isn't in fixed frequency, so '365 days' is used instead
rcParams['figure.figsize'] = 10,5
plt.plot(df, label='Original')
plt.plot(df.rolling('365D').mean(), label='Rolling mean')
plt.legend()
plt.show()

# %%
rcParams['figure.figsize'] = 10,5
plt.plot(df, label='Original')
plt.plot(df.expanding().mean(), label='Expanding mean')
plt.plot(df.expanding().std(), label='Expanding std')
plt.legend()
plt.show()

# %% [markdown]
# # 1. ARIMA model
# - Auto Regressive Integrated Moving Average
# - forecast based on past values
# - suitable for non-seasonal time series & not a random white noise
# - characterized by 3 terms: d, p, q
#     - d: number of differencing required to make the time series stationary
#     - p: order of the AR term
#     - q: order of the MA term
# - time series with seasonal patterns --> need to add seasonal terms --> SARIMA (Seasonal ARIMA)

# %% [markdown]
# # Order of differencing (d)

# %% [markdown]
# - Objective of differencing: convert the time series into stationary
#
# (ie. if the time series is already stationary, d=0)
#
# - Method of stationarity determination
#
# ADF test (Augmented Dickey Fuller test) is useful in determining if the series is stationary. ADF is in default of a null hypothesis that series is non-stationary, so if the p-value <0.05 and null hypothesis can be rejected.
#
# python tools for ADF test: https://www.statsmodels.org/stable/generated/statsmodels.tsa.stattools.adfuller.html
#
# - Method of converting the stationarity
#     - Differencing
#         - stabilise the mean of a time series by removing changes in the level of a time series
#         - eliminate/reduce the trend and seasonality
#     - Transformations
#         logarithms stabilise the variance of a time series

# %%
from statsmodels.tsa.stattools import adfuller

def adf(df):
    rcParams['figure.figsize'] = 10,5
    dftest = adfuller(df, autolag='AIC')
    adf = pd.Series(dftest[0:4], index=['Test statistics','p-value','number of lags used','number of observations'])
    #critical values are stored in dictionary format
    for key,value in dftest[4].items():
        adf['Critical values({})'.format(key)] = value
    return adf, df.plot()

# %%
#original series
adf(df)
# Out:
# (Test statistics              -0.071121
#  p-value                       0.952240
#  number of lags used          39.000000
#  number of observations    10747.000000
#  Critical values(1%)          -3.430959
#  Critical values(5%)          -2.861809
#  Critical values(10%)         -2.566913
#  dtype: float64,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f91590440d0>)

# %%
#1st order differencing
adf(df.diff().dropna())
# Out:
# (Test statistics          -1.756881e+01
#  p-value                   4.061374e-30
#  number of lags used       3.800000e+01
#  number of observations    1.074700e+04
#  Critical values(1%)      -3.430959e+00
#  Critical values(5%)      -2.861809e+00
#  Critical values(10%)     -2.566913e+00
#  dtype: float64,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f913c50cad0>)

# %%
#2nd order differencing
adf(df.diff().diff().dropna())
# Out:
# (Test statistics             -28.052124
#  p-value                       0.000000
#  number of lags used          39.000000
#  number of observations    10745.000000
#  Critical values(1%)          -3.430959
#  Critical values(5%)          -2.861809
#  Critical values(10%)         -2.566913
#  dtype: float64,
#  <matplotlib.axes._subplots.AxesSubplot at 0x7f913bf6c3d0>)

# %% [markdown]
# Both 1st & 2nd order differencing are able to make the seies stationary with p<0.05.
#
# However, it should be careful not to over-difference the series as it may affect the model parameters.
#
# - Method of determining the right order of differencing
#     1. Autocorrelation function plot (ACF plot)
#         - Terminalogy
#             - autocorrelation: correlation of observations and previous values in the same series
#             - lag: observations with previous time steps
#         - ACF plot reaches to zero fairly quick --> ideal order of differencing
#         - +ve for many lags (>=10), needs further differencing
#         - lag 1's autocorrelation too -ve --> probably over-differenced
#     - Interpretation
#         - confidence intervals (95%) are drawn as a cone
#         - correlation values outside the code are likely a correlation, instead of statistical fluke (by luck)
#     2. ndiffs() under pmdarima

# %%
from statsmodels.graphics.tsaplots import plot_acf, plot_pacf

# %%
plt.rcParams.update({'figure.figsize':(10,10), 'figure.dpi':120})
fig, axes = plt.subplots(3, 1, sharex=True)

plot_acf(df, ax=axes[0])
axes[0].set_title('Original series')

plot_acf(df.diff().dropna(), ax=axes[1])
axes[1].set_title('1st order differencing')

plot_acf(df.diff().diff().dropna(), ax=axes[2])
axes[2].set_title('2nd order differencing')

plt.show()

# %% [markdown]
# Lags in 2nd differencing fall into negative zone very quickly, indicating the series may have been over differenced.
# Thus, 1st differencing should be chosen.

# %%
pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in /opt/anaconda3/lib/python3.7/site-packages (1.8.2)
# Requirement already satisfied: numpy~=1.19.0 in /opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (1.19.5)
# Requirement already satisfied: urllib3 in /opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (1.25.9)
# Requirement already satisfied: scikit-learn>=0.22 in /opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.23.1)
# Requirement already satisfied: pandas>=0.19 in /opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (1.0.5)
# Requirement already satisfied: joblib>=0.11 in /opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.16.0)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.11.1)
# Requirement already satisfied: scipy>=1.3.2 in /opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (1.5.0)
# Requirement already satisfied: Cython!=0.29.18,>=0.29 in /opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.29.21)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (49.2.0.post20200714)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/anaconda3/lib/python3.7/site-packages (from scikit-learn>=0.22->pmdarima) (2.1.0)
# Requirement already satisfied: pytz>=2017.2 in /opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.19->pmdarima) (2020.1)
# Requirement already satisfied: python-dateutil>=2.6.1 in /opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: patsy>=0.5 in /opt/anaconda3/lib/python3.7/site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Requirement already satisfied: six>=1.5 in /opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas>=0.19->pmdarima) (1.15.0)
# Note: you may need to restart the kernel to use updated packages.

# %%
from statsmodels.tsa.arima_model import ARIMA
from pmdarima.arima.utils import ndiffs

# %% [markdown]
# There is another method to determine the order of differencing: ndiffs
#
# 3 tests can be choosen: ‘kpss’(default), ‘adf’, ‘pp’
#
# http://alkaline-ml.com/pmdarima/1.5.1/modules/generated/pmdarima.arima.ndiffs.html
#
# All tests show the same result: 1

# %%
# ADF Test
ndiffs(df, test='adf')  # 2

# KPSS test
ndiffs(df, test='kpss')  # 0

# PP test:
ndiffs(df, test='pp')  # 2
# Out:
# 1

# %% [markdown]
# # Order of  AR term (p)

# %% [markdown]
# - Method of finding p
#     - Partial Autocorrelation (PACF) plot
#         - correlation between the series and its lag excluding the contributions from the intermediate lags

# %% [markdown]
# https://i.stack.imgur.com/DjEKh.png

# %% [markdown]
# ![image.png](attachment:image.png)

# %%
plot_pacf(df.diff().dropna())
plt.show()

# %% [markdown]
# PACF lag 1 is significant (above the significance line) and lag 2 is insignificant, so p=1 should be chosen.

# %% [markdown]
# # Order of MA term (q)

# %% [markdown]
# - Definition of MA term (q):
#     -  error of the lagged forecast
# - Method of finding q
#     - ACF
#         - show no of MA terms required to remove autocorrelation in a stationarized series

# %%
plot_acf(df.diff().dropna())
plt.show()

# %% [markdown]
# Similar with the result of AR, lag 1 is also far above the significance line than others.
#
# q=1

# %%
model = ARIMA(df, order=(1,1,1))
model_fit = model.fit(disp=0)
print(model_fit.summary())
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:                D.Value   No. Observations:                10786
# Model:                 ARIMA(1, 1, 1)   Log Likelihood              -39041.522
# Method:                       css-mle   S.D. of innovations              9.031
# Date:                Thu, 29 Apr 2021   AIC                          78091.043
# Time:                        01:11:25   BIC                          78120.187
# Sample:                             1   HQIC                         78100.871
#
# =================================================================================
#                     coef    std err          z      P>|z|      [0.025      0.975]
# ---------------------------------------------------------------------------------
# const             0.1419      0.083      1.712      0.087      -0.021       0.304
# ar.L1.D.Value     0.7625      0.234      3.255      0.001       0.303       1.222
# ma.L1.D.Value    -0.7736      0.229     -3.372      0.001      -1.223      -0.324
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1            1.3115           +0.0000j            1.3115            0.0000
# MA.1            1.2927           +0.0000j            1.2927            0.0000
# -----------------------------------------------------------------------------

# %% [markdown]
# The P Values of the AR1 and MA1 terms have improved and are highly significant (< 0.05).

# %%
residuals = pd.DataFrame(model_fit.resid)
fig, ax = plt.subplots(1,2)
residuals.plot(title="Residuals", ax=ax[0])
residuals.plot(kind='kde', title='Density', ax=ax[1])
plt.show()

# %% [markdown]
# Although residual errors not mainly around zero, but the variance is uniform.
#
# Note: dynamic=False --> in-sample lagged values are used for prediction

# %%
model_fit.plot_predict(dynamic=False)
plt.show()

# %% [markdown]
# # Out-of-Time Cross validation

# %%
df.shape
# Out:
# (10787, 1)

# %%
#want to verify the recent 3 month-trend
#simply create train-test split that set test size around 90 rows
train = df[:10700]
test = df[10700:]

# %%
#arima(1,1,1)
model_val = ARIMA(train, order=(1,1,1))
model_val_fit = model_val.fit(disp=-1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)

# %%
# alpha=0.05 --> 95% conf
fc, se, conf = model_val_fit.forecast(87, alpha=0.05)

# %%
fc_series = pd.Series(fc, index=test.index)
lower_series = pd.Series(conf[:, 0], index=test.index)
upper_series = pd.Series(conf[:, 1], index=test.index)

# %%
plt.figure(figsize=(12,5), dpi=100)
plt.plot(train[10000:], label='Train')
plt.plot(test, label='Actual')
plt.plot(fc_series, label='Forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.15)
plt.title('Forecast vs Actual')
plt.legend(loc='upper left', fontsize=8)
plt.show()

# %% [markdown]
# ARIMA(1,1,1) model predict the gold price will drop in next 3 months and the actual price almost lie within the 95% confidence band. However, forecasts are consistently below the actual value.
#
# So, other parameters should be tried.

# %%
from sklearn.metrics import mean_squared_error
from statsmodels.tools.eval_measures import rmse

# %%
def arima(d,p,q):
    train = df[:10700]
    test = df[10700:]

    model_val = ARIMA(train, order=(d,p,q))
    model_val_fit = model_val.fit(disp=-1)
    print(model_val_fit.summary())

    fc, se, conf = model_val_fit.forecast(87, alpha=0.05)
    fc_series = pd.Series(fc, index=test.index)
    lower_series = pd.Series(conf[:, 0], index=test.index)
    upper_series = pd.Series(conf[:, 1], index=test.index)

    plt.figure(figsize=(12,5), dpi=100)
    plt.plot(train[10000:], label='Train')
    plt.plot(test, label='Actual')
    plt.plot(fc_series, label='Forecast')
    plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.15)
    plt.title('Forecast vs Actual')
    plt.legend(loc='upper left', fontsize=8)
    print('RSME:{}'.format(round(rmse(test, fc_series).mean(),4)))
    return plt.show()

# %%
arima(3,2,1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
#                              ARIMA Model Results
# ==============================================================================
# Dep. Variable:               D2.Value   No. Observations:                10698
# Model:                 ARIMA(3, 2, 1)   Log Likelihood              -38649.418
# Method:                       css-mle   S.D. of innovations              8.966
# Date:                Thu, 29 Apr 2021   AIC                          77310.836
# Time:                        01:11:35   BIC                          77354.503
# Sample:                             2   HQIC                         77325.567
#
# ==================================================================================
#                      coef    std err          z      P>|z|      [0.025      0.975]
# ----------------------------------------------------------------------------------
# const           1.066e-05   2.81e-05      0.380      0.704   -4.44e-05    6.57e-05
# ar.L1.D2.Value    -0.0158      0.010     -1.634      0.102      -0.035       0.003
# ar.L2.D2.Value    -0.0219      0.010     -2.262      0.024      -0.041      -0.003
# ar.L3.D2.Value     0.0278      0.010      2.879      0.004       0.009       0.047
# ma.L1.D2.Value    -1.0000      0.000  -3001.189      0.000      -1.001      -0.999
#                                     Roots
# =============================================================================
#                   Real          Imaginary           Modulus         Frequency
# -----------------------------------------------------------------------------
# AR.1           -1.4300           -2.7954j            3.1399           -0.3253
# AR.2           -1.4300           +2.7954j            3.1399            0.3253
# AR.3            3.6456           -0.0000j            3.6456           -0.0000
# MA.1            1.0000           +0.0000j            1.0000            0.0000
# -----------------------------------------------------------------------------
# RSME:96.3973

# %% [markdown]
# ARIMA(3,2,1) makes no difference. Since gold price is flutuating, similar to stock, it may be difficult to forcast a 3-month trend.
# Let's predict a shorter period.

# %%
def arima_size(day,d,p,q):
    n = 10787-day
    train = df[:n]
    test = df[n:]

    model_val = ARIMA(train, order=(d,p,q))
    model_val_fit = model_val.fit(disp=-1)

    fc, se, conf = model_val_fit.forecast(day, alpha=0.05)
    fc_series = pd.Series(fc, index=test.index)
    lower_series = pd.Series(conf[:, 0], index=test.index)
    upper_series = pd.Series(conf[:, 1], index=test.index)

    plt.figure(figsize=(12,5), dpi=100)
    plt.plot(train[10400:], label='Train')
    plt.plot(test, label='Actual')
    plt.plot(fc_series, label='Forecast')
    plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.15)
    plt.title('Forecast vs Actual')
    plt.legend(loc='upper left', fontsize=8)
    print('RSME:{}'.format(round(rmse(test, fc_series).mean(),4)))
    return plt.show()

# %%
#predict next 30 days
arima_size(day=30,d=1,p=1,q=1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# RSME:46.1067

# %%
#predict next 10 days
arima_size(day=10,d=1,p=1,q=1)
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# RSME:44.7756

# %% [markdown]
# # Auto Arima Forecast

# %% [markdown]
# search multiple combinations of p,d,q parameters in a stepwise approach
# --> choose the best model having the least AIC

# %%
import pmdarima as pm

# %%
train = df[:10757]
test = df[10757:]

# %%
model_auto_val = pm.auto_arima(train, start_p=1, start_q=1,
                      test='adf',       # adf test help find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model_auto_val.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,1,1)(0,0,0)[0] intercept   : AIC=77720.949, Time=2.77 sec
#  ARIMA(0,1,0)(0,0,0)[0] intercept   : AIC=77720.818, Time=0.18 sec
#  ARIMA(1,1,0)(0,0,0)[0] intercept   : AIC=77720.256, Time=0.38 sec
#  ARIMA(0,1,1)(0,0,0)[0] intercept   : AIC=77720.144, Time=0.45 sec
#  ARIMA(0,1,0)(0,0,0)[0]             : AIC=77721.591, Time=0.12 sec
#  ARIMA(0,1,2)(0,0,0)[0] intercept   : AIC=77717.496, Time=1.15 sec
#  ARIMA(1,1,2)(0,0,0)[0] intercept   : AIC=77711.550, Time=4.18 sec
#  ARIMA(2,1,2)(0,0,0)[0] intercept   : AIC=77679.888, Time=8.75 sec
#  ARIMA(2,1,1)(0,0,0)[0] intercept   : AIC=77711.510, Time=4.10 sec
#  ARIMA(3,1,2)(0,0,0)[0] intercept   : AIC=77714.876, Time=3.10 sec
#  ARIMA(2,1,3)(0,0,0)[0] intercept   : AIC=77715.497, Time=5.11 sec
#  ARIMA(1,1,3)(0,0,0)[0] intercept   : AIC=77712.964, Time=5.80 sec
#  ARIMA(3,1,1)(0,0,0)[0] intercept   : AIC=77713.044, Time=7.02 sec
#  ARIMA(3,1,3)(0,0,0)[0] intercept   : AIC=77718.185, Time=6.95 sec
#  ARIMA(2,1,2)(0,0,0)[0]             : AIC=77682.049, Time=3.92 sec
#
# Best model:  ARIMA(2,1,2)(0,0,0)[0] intercept
# Total fit time: 54.024 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                10757
# Model:               SARIMAX(2, 1, 2)   Log Likelihood              -38833.944
# Date:                Thu, 29 Apr 2021   AIC                          77679.888
# Time:                        01:14:52   BIC                          77723.587
# Sample:                             0   HQIC                         77694.627
#                               - 10757
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      0.4029      0.228      1.767      0.077      -0.044       0.850
# ar.L1         -0.7075      0.010    -69.268      0.000      -0.728      -0.688
# ar.L2         -0.9400      0.010    -97.926      0.000      -0.959      -0.921
# ma.L1          0.6895      0.012     58.713      0.000       0.666       0.712
# ma.L2          0.9191      0.011     82.326      0.000       0.897       0.941
# sigma2        80.0916      0.323    247.656      0.000      79.458      80.725
# ===================================================================================
# Ljung-Box (Q):                      109.59   Jarque-Bera (JB):            209332.91
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               3.08   Skew:                            -0.62
# Prob(H) (two-sided):                  0.00   Kurtosis:                        24.58
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %% [markdown]
# ARIMA(2,1,2) is suggested as it has smallest AIC (Akaike information criterio) value.
#
# AIC) is an estimator of prediction error and balance the trade-off between the goodness of fit and simplicity of the model.

# %%
plt.figure(figsize=(12,5), dpi=100)

fitted, confint = model_auto_val.predict(30, return_conf_int=True)

# make series for plotting purpose
auto_series = pd.Series(fitted, index=test.index)
lower_series = pd.Series(confint[:, 0], index=test.index)
upper_series = pd.Series(confint[:, 1], index=test.index)

plt.plot(train[10400:], label='Train')
plt.plot(test, label='Actual')
plt.plot(auto_series, label='Forecast')
plt.fill_between(lower_series.index, lower_series, upper_series, color='k', alpha=.15)
plt.title('Forecast vs Actual in next 30 days')
plt.legend(loc='upper left', fontsize=12)
print('RSME:{}'.format(round(rmse(test, auto_series).mean(),4)))
plt.show()
# Out:
# RSME:45.9645

# %% [markdown]
# rmse of ARIMA(2,1,2) is 46.018, while that of ARIMA(1,1,1) is 46.1067

# %% [markdown]
# # 2. Prophet
# - open source software released by Facebook
# - based on an additive model
# - non-linear trends are fit with yearly, weekly, and daily seasonality, plus holiday effects
# - works best with time series having strong seasonal effects and several seasons of historical data

# %%
conda install -c conda-forge fbprophet -y
# Out:
# Collecting package metadata (current_repodata.json): done
# Solving environment: -
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::conda-build==3.21.4=py37hecd8cb5_0
# failed with initial frozen solve. Retrying with flexible solve.
# Solving environment: failed with repodata from current_repodata.json, will retry with next repodata source.
# Collecting package metadata (repodata.json): done
# Solving environment: |
# The environment is inconsistent, please check the package plan carefully
# The following packages are causing the inconsistency:
#
#   - defaults/osx-64::conda-build==3.21.4=py37hecd8cb5_0
# /
# Warning: 8 possible package resolutions (only showing differing packages):
#   - anaconda/osx-64::ca-certificates-2020.6.24-0, anaconda/osx-64::certifi-2020.6.20-py37_0, anaconda/osx-64::openssl-1.1.1g-h1de35cc_0
#   - anaconda/osx-64::ca-certificates-2020.6.24-0, anaconda/osx-64::certifi-2020.6.20-py37_0, defaults/osx-64::openssl-1.1.1g-h1de35cc_0
#   - anaconda/osx-64::ca-certificates-2020.6.24-0, defaults/osx-64::certifi-2020.6.20-py37_0, defaults/osx-64::openssl-1.1.1g-h1de35cc_0
#   - anaconda/osx-64::ca-certificates-2020.6.24-0, anaconda/osx-64::openssl-1.1.1g-h1de35cc_0, defaults/osx-64::certifi-2020.6.20-py37_0
#   - defaults/osx-64::ca-certificates-2020.6.24-0, defaults/osx-64::certifi-2020.6.20-py37_0, defaults/osx-64::openssl-1.1.1g-h1de35cc_0
#   - anaconda/osx-64::openssl-1.1.1g-h1de35cc_0, defaults/osx-64::ca-certificates-2020.6.24-0, defaults/osx-64::certifi-2020.6.20-py37_0
#   - anaconda/osx-64::certifi-2020.6.20-py37_0, defaults/osx-64::ca-certificates-2020.6.24-0, defaults/osx-64::openssl-1.1.1g-h1de35cc_0
#   - anaconda/osx-64::certifi-2020.6.20-py37_0, anaconda/osx-64::openssl-1.1.1g-h1de35cc_0, defaults/osx-64::ca-certificates-2020.6.24done
#
# ## Package Plan ##
#
#   environment location: /opt/anaconda3
#
#   added / updated specs:
#     - fbprophet
#
#
# The following packages will be downloaded:
#
#     package                    |            build
#     ---------------------------|-----------------
#     fbprophet-0.6              |   py37h4a8c4bd_0         623 KB  conda-forge
#     pystan-2.17.1.0            |py37h1702cab_1003        14.2 MB  conda-forge
#     ------------------------------------------------------------
#                                            Total:        14.8 MB
#
# The following NEW packages will be INSTALLED:
#
#   cctools            conda-forge/osx-64::cctools-949.0.1-h22b1bf0_0
#   cctools_osx-64     conda-forge/osx-64::cctools_osx-64-949.0.1-h5ba7a2e_0
#   clang              conda-forge/osx-64::clang-9.0.1-default_hf57f61e_0
#   clang_osx-64       conda-forge/osx-64::clang_osx-64-9.0.1-h05bbb7f_0
#   clangxx            conda-forge/osx-64::clangxx-9.0.1-default_hf57f61e_0
#   clangxx_osx-64     conda-forge/osx-64::clangxx_osx-64-9.0.1-h05bbb7f_2
#   compiler-rt        conda-forge/osx-64::compiler-rt-9.0.1-h6a512c6_3
#   compiler-rt_osx-64 conda-forge/noarch::compiler-rt_osx-64-9.0.1-h99342c6_3
#   conda              conda-forge/osx-64::conda-4.10.1-py37hf985489_0
#   convertdate        conda-forge/noarch::convertdate-2.3.2-pyhd8ed1ab_0
#   ephem              conda-forge/osx-64::ephem-3.7.7.1-py37h60d8a13_1
#   fbprophet          conda-forge/osx-64::fbprophet-0.6-py37h4a8c4bd_0
#   hijri-converter    conda-forge/noarch::hijri-converter-2.1.1-pyhd8ed1ab_0
#   holidays           conda-forge/noarch::holidays-0.11.1-pyhd8ed1ab_0
#   korean_lunar_cale~ conda-forge/noarch::korean_lunar_calendar-0.2.1-pyh9f0ad1d_0
#   ld64               conda-forge/osx-64::ld64-530-0
#   ld64_osx-64        conda-forge/osx-64::ld64_osx-64-530-h3c32e8a_0
#   lunarcalendar      conda-forge/noarch::lunarcalendar-0.0.9-py_0
#   pymeeus            conda-forge/noarch::pymeeus-0.5.10-pyhd8ed1ab_0
#   pystan             conda-forge/osx-64::pystan-2.17.1.0-py37h1702cab_1003
#   python_abi         conda-forge/osx-64::python_abi-3.7-1_cp37m
#   tapi               conda-forge/osx-64::tapi-1000.10.8-h879752b_4
#
#
#
# Downloading and Extracting Packages
# fbprophet-0.6        | 623 KB    | ##################################### | 100%
# pystan-2.17.1.0      | 14.2 MB   | ##################################### | 100%
# Preparing transaction: done
# Verifying transaction: done
# Executing transaction: done
#
# Note: you may need to restart the kernel to use updated packages.

# %%
from fbprophet import Prophet

# %%
#DataFrame must have a specific format
#1st column is ‘ds‘ and contain the date-times
#2nd column is ‘y‘ and contain the observations

df_fb = pd.read_csv('gold_price_data.csv')
df_fb = df_fb.rename(columns={'Date':'ds','Value':'y'})

train_fb = df_fb[:10757]
test_fb = df_fb[10757:]

model2 = Prophet()
model2.fit(train_fb)
# Out:
# INFO:fbprophet:Disabling daily seasonality. Run prophet with daily_seasonality=True to override this.

# %%
future = model2.make_future_dataframe(periods=300)
forecast_fb = model2.predict(future)

# %%
train_fb['ds'] = pd.to_datetime(train_fb['ds'], format='%Y-%m-%d')
test_fb['ds'] = pd.to_datetime(test_fb['ds'], format='%Y-%m-%d')
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   """Entry point for launching an IPython kernel.
# /opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy

# %%
forecast_fb_plot = forecast_fb[10757:]

plt.figure(figsize=(15,5))
plt.plot(train_fb.ds, train_fb['y'], label = 'Train')
plt.plot(test_fb.ds, test_fb['y'], label='Test')
plt.plot(forecast_fb_plot.ds, forecast_fb_plot['yhat'], label='Prophet Forecast')
plt.legend(loc='best')

plt.show()

# %%
print('RSME:{}'.format(round(rmse(test_fb.y, forecast_fb_plot['yhat'][:30]).mean(),4)))
# Out:
# RSME:370.5107

# %% [markdown]
# Prophet predict the gold price will have a great drop(green line), rather than increase.
# However, the actual gold price keep increasing instead. Incorrect prediction leads to big rsme.

# %% [markdown]
# # 3. Holt-Winters
# - uses exponential smoothing to encode lots of values from the past by computing the combined effects of value, trend and seasonality

# %%
from statsmodels.tsa.holtwinters import SimpleExpSmoothing
from statsmodels.tsa.holtwinters import ExponentialSmoothing

# %%
train_hw = df[:10757]
test_hw = df[10757:]

future2 = ExponentialSmoothing(train_hw, trend='mul').fit()
forecast_hw = future2.forecast(30)

date_index = pd.date_range('2020-02-03', periods=30, freq='D')
forecast_hw.index = date_index

plt.figure(figsize=(16,8))
plt.plot(train_hw[10000:], label='Train')
plt.plot(test_hw, label='Test')
plt.plot(forecast_hw, label='Holt_Winter Forecast')
plt.legend(loc='best')

plt.show()
# Out:
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:218: ValueWarning: A date index has been provided, but it has no associated frequency information and so will be ignored when e.g. forecasting.
#   ' ignored when e.g. forecasting.', ValueWarning)
# /opt/anaconda3/lib/python3.7/site-packages/statsmodels/tsa/base/tsa_model.py:583: ValueWarning: No supported index is available. Prediction results will be given with an integer index beginning at `start`.
#   ValueWarning)

# %%
print('RSME:{}'.format(round(rmse(test_hw, forecast_hw).mean(),4)))
# Out:
# RSME:44.9459

# %%
Summary = {'Method':['ARIMA(1,1,1) (manual)','ARIMA(2,1,2) (auto)','Prophet','Holt-Winters'],
              'RSME':[46.1067,round(rmse(test, auto_series).mean(),4),round(rmse(test_fb.y, forecast_fb_plot['yhat'][:30]).mean(),4),round(rmse(test_hw, forecast_hw).mean(),4)]}

pd.DataFrame(Summary)
# Out:
#                   Method      RSME
# 0  ARIMA(1,1,1) (manual)   46.1067
# 1    ARIMA(2,1,2) (auto)   45.9645
# 2                Prophet  370.5107
# 3           Holt-Winters   44.9459
